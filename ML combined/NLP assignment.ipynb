# %% [markdown]
# In this assignment students have to find the frequency of words in a
# webpage. User can use urllib and BeautifulSoup to extract text from
# webpage.

# %%
import nltk
import urllib.request
from bs4 import BeautifulSoup
import re
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
response = urllib.request.urlopen('http://php.net/')
html = response.read()
soup = BeautifulSoup(html,"html5lib")

# %%
text = soup.get_text()

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\melchiz
# [nltk_data]     shroff\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
tokens = [t for t in text.split()] 
clean_tokens = tokens[:] 
sr = stopwords.words('english') 
for token in tokens: 
    if token in stopwords.words('english'): 
        clean_tokens.remove(token) 
freq = nltk.FreqDist(clean_tokens) 
for key,val in freq.items(): 
    print (str(key) + ':' + str(val))
# Out:
# PHP::1
# Hypertext:1
# Preprocessor:1
# Downloads:1
# Documentation:1
# Get:1
# Involved:1
# Help:1
# Getting:1
# Started:1
# Introduction:2
# A:1
# simple:1
# tutorial:1
# Language:2
# Reference:2
# Basic:2
# syntax:1
# Types:1
# Variables:2
# Constants:1
# Expressions:1
# Operators:1
# Control:2
# Structures:1
# Functions:1
# Classes:2
# Objects:1
# Namespaces:1
# Errors:1
# Exceptions:2
# Generators:1
# References:1
# Explained:1
# Predefined:3
# Interfaces:1
# Context:1
# options:1
# parameters:1
# Supported:1
# Protocols:1
# Wrappers:1
# Security:4
# General:1
# considerations:1
# Installed:2
# CGI:1
# binary:1
# Apache:1
# module:1
# Session:2
# Filesystem:1
# Database:3
# Error:1
# Reporting:1
# Using:2
# Register:1
# Globals:1
# User:2
# Submitted:1
# Data:1
# Magic:1
# Quotes:1
# Hiding:1
# PHP:150
# Keeping:1
# Current:1
# Features:1
# HTTP:1
# authentication:1
# Cookies:1
# Sessions:1
# Dealing:1
# XForms:1
# Handling:1
# file:10
# uploads:1
# remote:1
# files:10
# Connection:1
# handling:1
# Persistent:1
# Connections:1
# Command:2
# line:1
# usage:1
# Garbage:1
# Collection:1
# DTrace:1
# Dynamic:1
# Tracing:1
# Function:1
# Affecting:1
# PHP's:1
# Behaviour:1
# Audio:1
# Formats:1
# Manipulation:2
# Authentication:1
# Services:3
# Line:1
# Specific:2
# Extensions:16
# Compression:1
# Archive:1
# Cryptography:1
# Date:1
# Time:1
# Related:4
# File:1
# System:1
# Human:1
# Character:1
# Encoding:1
# Support:1
# Image:1
# Processing:2
# Generation:1
# Mail:1
# Mathematical:1
# Non-Text:1
# MIME:1
# Output:1
# Process:1
# Other:3
# Search:1
# Engine:1
# Server:1
# Text:1
# Variable:1
# Type:1
# Web:2
# Windows:20
# Only:1
# XML:1
# GUI:1
# Keyboard:1
# Shortcuts?:1
# This:24
# help:1
# j:1
# Next:2
# menu:2
# item:2
# k:1
# Previous:2
# g:6
# p:1
# man:2
# page:4
# n:1
# G:1
# Scroll:2
# bottom:1
# top:1
# h:1
# Goto:2
# homepage:1
# search(current:1
# page):1
# /:1
# Focus:1
# search:1
# box:1
# popular:2
# general-purpose:1
# scripting:1
# language:1
# especially:1
# suited:1
# web:1
# development.:1
# Fast,:1
# flexible:1
# pragmatic,:1
# powers:1
# everything:1
# blog:1
# websites:1
# world.:1
# Download:1
# 7.4.11·Release:1
# Notes·Upgrading:3
# 7.3.23·Release:1
# 7.2.34·Release:1
# 16:1
# Oct:8
# 2020:26
# 8.0.0:17
# Release:10
# Candidate:10
# 2:5
# available:8
# testing:17
# The:63
# team:25
# pleased:9
# announce:9
# ninth:1
# release:58
# 8.0.0,:9
# 2.:3
# At:3
# time,:3
# we're:4
# planning:3
# adjust:3
# GA:3
# date,:3
# however:4
# may:3
# change:3
# course:3
# RC:4
# cycle.:3
# updated:3
# schedule:3
# can,:3
# always,:3
# found:46
# Wiki:2
# 8.0.:2
# For:40
# source:41
# downloads:41
# please:25
# visit:25
# download:9
# page.:9
# Please:18
# carefully:9
# test:18
# version:21
# report:9
# issues:9
# bug:18
# reporting:9
# system.:9
# DO:9
# NOT:9
# use:9
# production,:9
# early:9
# version.:24
# information:9
# new:9
# features:9
# changes,:9
# read:9
# NEWS:9
# file,:9
# UPGRADING:9
# complete:9
# list:25
# upgrading:9
# notes.:9
# These:9
# also:11
# archive.:9
# next:9
# 3,:3
# planned:9
# 29:1
# 2020.:9
# signatures:9
# manifest:9
# QA:9
# site.:9
# Thank:9
# helping:9
# us:9
# make:9
# better.:9
# 01:4
# 1:7
# eighth:1
# 1.:3
# 2,:3
# 15:1
# 7.3.23:2
# Released!:14
# development:17
# announces:16
# immediate:16
# availability:16
# 7.3.23.:1
# security:11
# release.:13
# All:15
# 7.3:6
# users:18
# encouraged:15
# upgrade:16
# page,:16
# binaries:16
# windows.php.net/download/.:16
# changes:16
# recorded:16
# ChangeLog.:16
# 7.4.11:2
# 7.4.11.:1
# 7.4:6
# 7.2.34:2
# 7.2.34.:1
# 7.2:3
# 17:2
# Sep:6
# Beta:14
# 4:2
# seventh:1
# 4.:1
# point:2
# cycle:2
# would:1
# normally:1
# RC1,:1
# still:1
# finalizing:1
# JIT:1
# squaring:1
# away:1
# named:1
# arguments,:1
# we've:1
# opted:1
# extra:1
# beta:1
# plans:1
# start:1
# two:1
# weeks.:1
# Wiki.:7
# 1,:3
# 03:3
# 3:5
# sixth:1
# 3.:2
# continues:5
# 8.0:6
# cycle,:6
# rough:6
# outline:6
# specified:6
# 7.4.10:2
# 7.4.10.:1
# fix:7
# 7.3.22:2
# 7.3.22.:1
# 21:1
# Aug:7
# 8.0.0beta2:1
# fifth:1
# 06:5
# 7.4.9:2
# 7.4.9.:1
# fourth:1
# 20:1
# 7.3.21:2
# 7.3.21.:1
# 7.2.33:2
# 7.2.33.:1
# 23:2
# Jul:7
# Alpha:11
# third:1
# 09:4
# 7.4.8:2
# 7.4.8.:1
# impacting:3
# official:6
# builds:3
# PHP.:3
# windows:3
# running:3
# build,:3
# contains:5
# patched:3
# libcurl:3
# addressing:3
# CVE-2020-8169.:3
# consumers:3
# PHP,:3
# 7.2.32:2
# 7.2.32.:1
# functionally:1
# identical:1
# 7.2.31:3
# necessary.:1
# 7.3.20:2
# 7.3.20.:1
# second:1
# 25:1
# Jun:3
# first:1
# starts:1
# 9:1
# 11:2
# 7.4.7:2
# 7.4.7.:1
# 7.3.19:2
# Released:3
# 7.3.19.:1
# 14:3
# May:3
# 7.4.6:2
# 7.4.6.:1
# several:2
# fixes.:2
# 7.3.18:3
# 7.2.31.:1
# Older:1
# News:1
# Entries:1
# Upcoming:1
# conferencesThe:1
# Online:1
# Conference:3
# 2021International:1
# Munich:1
# 2020International:1
# Berlin:1
# 2020PHP.RUHR:1
# -:1
# Development:1
# &:1
# Digital:1
# Commerce:1
# Group:2
# Events:1
# Special:1
# Thanks:1
# Social:1
# media:1
# @official_php:1
# Copyright:1
# ©:1
# 2001-2020:1
# My:1
# PHP.net:2
# Contact:1
# sites:1
# Privacy:1
# policy:1
